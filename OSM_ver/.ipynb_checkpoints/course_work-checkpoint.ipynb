# %%
#Create Map Graph  
library (ggmap)
library (osmar)
library(prettymapr)

#Import data on Greater London
src <- osmsource_api ()

# bb <- center_bbox(-0.091397, 51.514695, 400, 400)
bb <- osmar::corner_bbox(-0.1430397, 51.5265924, -0.1214227, 51.5400746)
ua <- osmar::get_osm(bb, source = src)
#The osmdata contains an osmar object, which has all the 'nodes' and 'ways' associated with the data.
#Two ways of visualizing
osmar::plot_nodes(ua)
osmar::plot_ways(ua, add=T)
# Out:
# plot without title

# %%
#Subset the data such that we only have data associated with the roads
hways_data <- subset(ua, way_ids = find(ua, way(tags(k == "highway"))))
hways <- find(hways_data, way(tags(k == "name")))
hways <- find_down(ua, way(hways))
hways_data <- subset(ua, ids = hways)
plot(hways_data)
# Out:
# plot without title

# %%
#visualization
par(bg = "black")
osmar::plot_ways(hways_data, col="blue", bg ='green')
osmar::plot_nodes(hways_data, pch=19, cex=0.1, add=T, col="red")
# Out:
# plot without title

# %%
#convert to igraph
par(bg = "black")
hways_graph = as_igraph(hways_data)
hways_graph = as.undirected(hways_graph)
V(hways_graph)$name <- 1:length(V(hways_graph))
plot(hways_graph, vertex.size=2, edge.color="blue", vertex.label.color="red",vertex.label.cex=0.5)
jpeg('igraph.jpg')
# vertex.label=NA
# Out:
# Plot with title “”

# %%
adjacent_vertices(hways_graph, 297)
# Out:
# $`297`
# + 2/2195 vertices, named, from b5df628:
# [1] 296 298

# %%
#Let's get the trace data
library(plotKML)
library(urltools)
library(rgdal)

url = "http://api.openstreetmap.org/api/0.6/trackpoints?bbox=12&page=pagenumber"
mat = matrix(bb)[,1]
val = capture.output(mat[])
url <- param_set(url, key = "bbox", value = "-0.1430397,51.5265924,-0.1214227,51.5400746")
setwd("data")
for (i in 0:20){
    url <- param_set(url, key = "page", value = i)
    filename <- paste(i,"trace_data.gpx")
    download.file(url, destfile=filename)
}
files <- dir(pattern = "\\.gpx")
setwd("../")
#Read in GPX files that are located in the working directory

# %%
for (i in 1:length(files)){
    setwd("data")
    route <- readOGR(files[i], "tracks")
    coordinates = coordinates(route)
    setwd("../trace")
    for (j in 1:length(coordinates)) {
        for (k in 1:length(coordinates[[j]])) {
            coor = coordinates(route)[[j]][[k]]
#             index <- 0 : nrow(coor)
            latitude <- coor[,2]
            longitude <- coor[,1]
            routes <- data.frame(cbind(latitude, longitude))
            filename <- paste(i, j, k, "trace_data.csv")
            write.csv(routes, filename)
        }
    }
    setwd("../")
}
# Out:
# OGR data source with driver: GPX
# Source: "0 trace_data.gpx", layer: "tracks"
# with 8 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "1 trace_data.gpx", layer: "tracks"
# with 4 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "10 trace_data.gpx", layer: "tracks"
# with 3 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "11 trace_data.gpx", layer: "tracks"
# with 30 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "12 trace_data.gpx", layer: "tracks"
# with 23 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "13 trace_data.gpx", layer: "tracks"
# with 7 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "14 trace_data.gpx", layer: "tracks"
# with 8 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "15 trace_data.gpx", layer: "tracks"
# with 12 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "16 trace_data.gpx", layer: "tracks"
# with 1 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "17 trace_data.gpx", layer: "tracks"
# with 1 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "18 trace_data.gpx", layer: "tracks"
# with 1 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "19 trace_data.gpx", layer: "tracks"
# with 2 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "2 trace_data.gpx", layer: "tracks"
# with 10 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "20 trace_data.gpx", layer: "tracks"
# with 2 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "3 trace_data.gpx", layer: "tracks"
# with 4 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "4 trace_data.gpx", layer: "tracks"
# with 23 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "5 trace_data.gpx", layer: "tracks"
# with 9 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "6 trace_data.gpx", layer: "tracks"
# with 4 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "7 trace_data.gpx", layer: "tracks"
# with 10 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "8 trace_data.gpx", layer: "tracks"
# with 1 features
# It has 12 fields
# OGR data source with driver: GPX
# Source: "9 trace_data.gpx", layer: "tracks"
# with 7 features
# It has 12 fields

# %%
map <- qmap(location = c(left = -0.1430397, bottom = 51.5265924, right = -0.1214227, top=51.5400746), maptype="toner", zoom =15, color = 'bw')
setwd("trace/")
traces <- dir(pattern = "\\.csv")
for (i in 1:length(traces)){
    trace <- read.csv(traces[i])
    map <- map + geom_path(aes(x = longitude, y = latitude), colour="blue", data = trace, alpha=0.3)
}
setwd("../")
# Out:
# maptype = "toner" is only available with source = "stamen".
# resetting to source = "stamen"...
# Warning message:
# “`panel.margin` is deprecated. Please use `panel.spacing` property instead”

# %%
map
# Out:
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# plot without title

# %%
library(curl)
req <- curl_fetch_memory("http://router.project-osrm.org/route/v1/driving/13.388860,52.517037;13.397634,52.529407;13.428555,52.523219?overview=false")
str(req)

# %%
hoge <- readOGR(files[1], "tracks")
range(as.character(hoge$trkseg))
# Out:
# OGR data source with driver: GPX
# Source: "0 trace_data.gpx", layer: "tracks"
# with 8 features
# It has 12 fields
# Warning message in min(x, na.rm = na.rm):
# “no non-missing arguments, returning NA”Warning message in max(x, na.rm = na.rm):
# “no non-missing arguments, returning NA”
# [1] NA NA

# %%
nrow(hoge[1])
# Out:
# [1] 8

# %%
hoge
# Out:
#                                     geometry
# 0   MULTILINESTRING((-0.122593 51.5266 ...))
# 1   MULTILINESTRING((-0.14293 51.53882 ...))
# 2 MULTILINESTRING((-0.1214634 51.53089 ...))
# 3 MULTILINESTRING((-0.1214458 51.53083 ...))
# 4 MULTILINESTRING((-0.1278455 51.53271 ...))
# 5 MULTILINESTRING((-0.1300198 51.53982 ...))
# 6  MULTILINESTRING((-0.135696 51.54004 ...))
# 7 MULTILINESTRING((-0.1240187 51.52662 ...))
#                                                                                 name
# 0                                                                               <NA>
# 1                                                                     activities.zip
# 2                                                                  _20170725_Twr.gpx
# 3                                                                 _20170724_Lndn.gpx
# 4                                                         _20170724_Lndn_StPncrs.gpx
# 5                                                           _20170724_Ntghm_Lndn.gpx
# 6 And_finally_Gamlingay_to_Google_London_and_I_can_remove_touring_bag_from_bike_.gpx
# 7                                                                 20170609135754.gpx
#    cmt                         desc  src link1_href link1_text link1_type
# 0 <NA>                         <NA> <NA>       <NA>       <NA>       <NA>
# 1 <NA>                      Cycling <NA>       <NA>       <NA>       <NA>
# 2 <NA>                        Tower <NA>       <NA>       <NA>       <NA>
# 3 <NA>                       London <NA>       <NA>       <NA>       <NA>
# 4 <NA>          London King's Cross <NA>       <NA>       <NA>       <NA>
# 5 <NA>          Nottingham - London <NA>       <NA>       <NA>       <NA>
# 6 <NA>    Gamlingay missing piueces <NA>       <NA>       <NA>       <NA>
# 7 <NA> Simon's bicycle ride or walk <NA>       <NA>       <NA>       <NA>
#   link2_href link2_text link2_type number type
# 0       <NA>       <NA>       <NA>     NA <NA>
# 1       <NA>       <NA>       <NA>     NA <NA>
# 2       <NA>       <NA>       <NA>     NA <NA>
# 3       <NA>       <NA>       <NA>     NA <NA>
# 4       <NA>       <NA>       <NA>     NA <NA>
# 5       <NA>       <NA>       <NA>     NA <NA>
# 6       <NA>       <NA>       <NA>     NA <NA>
# 7       <NA>       <NA>       <NA>     NA <NA>
